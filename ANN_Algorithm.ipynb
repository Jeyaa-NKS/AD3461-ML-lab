# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeyaa-NKS/AD3461-ML-lab/blob/main/ANN_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %%
import tensorflow as tf
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
from IPython.display import Image

# Load breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the neural network architecture
model = Sequential([
    Dense(10, input_dim=30, activation='relu'),
    Dense(5, activation='softmax'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model on the training set
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=100, batch_size=10)

# Predict the output for the testing set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)

# Calculate the accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Visualize the neural network architecture
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
Image(filename='model.png')
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 7ms/step - loss: 0.6664 - accuracy: 0.6176 - val_loss: 0.6467 - val_accuracy: 0.6667
# Epoch 2/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.6176 - val_loss: 0.6463 - val_accuracy: 0.6667
# Epoch 3/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6176 - val_loss: 0.6452 - val_accuracy: 0.6667
# Epoch 4/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.6176 - val_loss: 0.6442 - val_accuracy: 0.6667
# Epoch 5/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.6176 - val_loss: 0.6441 - val_accuracy: 0.6667
# Epoch 6/100
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.6176 - val_loss: 0.6437 - val_accuracy: 0.6667
# Epoch 7/100
# ...
